# %%
file = open("bdata.txt")

line = file.read().replace("\n", " ")

# %%
type(line)
# Out:
# str

# %%
len(line)
# Out:
# 266894

# %%
line[0]
# Out:
# '['

# %%
line
# Out:
# '[{"id": "100", "timestamp": "2020-11-16T11:55:55.000", "station_name": "Orleans St & Merchandise Mart Plaza", "total_docks": "35", "docks_in_service": "35", "available_docks": "20", "available_bikes": "15", "percent_full": "43", "status": "In Service", "latitude": "41.888243", "longitude": "-87.63639", "location": {"type": "Point", "coordinates": [-87.63639, 41.888243]}, "record": "10020201116115555"}, {"id": "101", "timestamp": "2020-11-16T11:55:55.000", "station_name": "63rd St Beach", "total_docks": "15", "docks_in_service": "15", "available_docks": "3", "available_bikes": "12", "percent_full": "80", "status": "In Service", "latitude": "41.781016372", "longitude": "-87.57611976", "location": {"type": "Point", "coordinates": [-87.5761197602, 41.78101637196]}, "record": "10120201116115555"}, {"id": "102", "timestamp": "2020-11-16T11:55:55.000", "station_name": "Stony Island Ave & 67th St", "total_docks": "11", "docks_in_service": "11", "available_docks": "4", "available_bikes": "7"
# ...

# %%
line.replace("'", "")
# Out:
# '[{"id": "100", "timestamp": "2020-11-16T11:55:55.000", "station_name": "Orleans St & Merchandise Mart Plaza", "total_docks": "35", "docks_in_service": "35", "available_docks": "20", "available_bikes": "15", "percent_full": "43", "status": "In Service", "latitude": "41.888243", "longitude": "-87.63639", "location": {"type": "Point", "coordinates": [-87.63639, 41.888243]}, "record": "10020201116115555"}, {"id": "101", "timestamp": "2020-11-16T11:55:55.000", "station_name": "63rd St Beach", "total_docks": "15", "docks_in_service": "15", "available_docks": "3", "available_bikes": "12", "percent_full": "80", "status": "In Service", "latitude": "41.781016372", "longitude": "-87.57611976", "location": {"type": "Point", "coordinates": [-87.5761197602, 41.78101637196]}, "record": "10120201116115555"}, {"id": "102", "timestamp": "2020-11-16T11:55:55.000", "station_name": "Stony Island Ave & 67th St", "total_docks": "11", "docks_in_service": "11", "available_docks": "4", "available_bikes": "7"
# ...

# %%
import ast
dict_Station = ast.literal_eval(line)

# %%
dict_Station
# Out:
# [{'id': '100',
#   'timestamp': '2020-11-16T11:55:55.000',
#   'station_name': 'Orleans St & Merchandise Mart Plaza',
#   'total_docks': '35',
#   'docks_in_service': '35',
#   'available_docks': '20',
#   'available_bikes': '15',
#   'percent_full': '43',
#   'status': 'In Service',
#   'latitude': '41.888243',
#   'longitude': '-87.63639',
#   'location': {'type': 'Point', 'coordinates': [-87.63639, 41.888243]},
#   'record': '10020201116115555'},
#  {'id': '101',
#   'timestamp': '2020-11-16T11:55:55.000',
#   'station_name': '63rd St Beach',
#   'total_docks': '15',
#   'docks_in_service': '15',
#   'available_docks': '3',
#   'available_bikes': '12',
#   'percent_full': '80',
#   'status': 'In Service',
#   'latitude': '41.781016372',
#   'longitude': '-87.57611976',
#   'location': {'type': 'Point',
#    'coordinates': [-87.5761197602, 41.78101637196]},
#   'record': '10120201116115555'},
#  {'id': '102',
#   'timestamp': '2020-11-16T11:55:55.000',
# ...

# %%
for i in dict_Station:
    print(str(i['station_name']) + " had "+str(i['available_bikes']) + " bikes on " + i['timestamp'])

print("""


##########################################################################################


""")    
    
    
print("Stations:" +  " Bikes Available" + str(sum(int(i['available_bikes']) for i in dict_Station))
    + " Docks Available " + str(sum(int(i['total_docks']) for i in dict_Station)))
# Out:
# Orleans St & Merchandise Mart Plaza had 15 bikes on 2020-11-16T11:55:55.000
# 63rd St Beach had 12 bikes on 2020-11-16T11:55:55.000
# Stony Island Ave & 67th St had 7 bikes on 2020-11-16T11:55:55.000
# Clinton St & Polk St had 9 bikes on 2020-11-16T11:55:55.000
# State St & Pearson St had 18 bikes on 2020-11-16T11:55:55.000
# Desplaines St & Jackson Blvd had 22 bikes on 2020-11-16T11:55:55.000
# Halsted St & Polk St had 11 bikes on 2020-11-16T11:55:55.000
# 900 W Harrison St had 7 bikes on 2020-11-16T11:55:55.000
# Dearborn St & Erie St had 19 bikes on 2020-11-16T11:55:55.000
# Sedgwick St & Huron St had 12 bikes on 2020-11-16T11:55:55.000
# Jeffery Blvd & 71st St had 2 bikes on 2020-11-16T11:55:55.000
# Green St & Randolph St had 7 bikes on 2020-11-16T11:55:55.000
# Bissell St & Armitage Ave had 2 bikes on 2020-11-16T11:55:55.000
# Sheffield Ave & Waveland Ave had 12 bikes on 2020-11-16T11:55:55.000
# Sheffield Ave & Wellington Ave had 9 bikes on 2020-11-16T11:55:55.000
# ...

# %%
sum(int(i['available_bikes']) for i in dict_Station)
# Out:
# 5099

# %%
 [j for j in i['id'] ]

# %%
len(dict_Station)
# Out:
# 669

# %%
a = [1,2,3,4,5]
for i in a:
    print(sum(i))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-190-6eef957013dc> in <module>
#       1 a = [1,2,3,4,5]
#       2 for i in a:
# ----> 3     print(sum(i))
#
# TypeError: 'int' object is not iterable

# %%
[x[x['station_name']]== 'Orleans St & Merchandise Mart Plaza' for x in dict_Station]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-d6221dea79f2> in <module>
# ----> 1 [x[x['station_name']]== 'Orleans St & Merchandise Mart Plaza' for x in dict_Station]
#
# <ipython-input-69-d6221dea79f2> in <listcomp>(.0)
# ----> 1 [x[x['station_name']]== 'Orleans St & Merchandise Mart Plaza' for x in dict_Station]
#
# KeyError: 'Orleans St & Merchandise Mart Plaza'

# %%
dict_Station[0]
# Out:
# {'id': '100',
#  'timestamp': '2020-11-16T11:55:55.000',
#  'station_name': 'Orleans St & Merchandise Mart Plaza',
#  'total_docks': '35',
#  'docks_in_service': '35',
#  'available_docks': '20',
#  'available_bikes': '15',
#  'percent_full': '43',
#  'status': 'In Service',
#  'latitude': '41.888243',
#  'longitude': '-87.63639',
#  'location': {'type': 'Point', 'coordinates': [-87.63639, 41.888243]},
#  'record': '10020201116115555'}

# %%
def get_station_info(id =None, ts=None, s_name=None, td=None, dis=None, ad=None, ab=None):
    for i in dict_Station:

# %%
line
# Out:
# '[{"id": "100", "timestamp": "2020-11-16T11:55:55.000", "station_name": "Orleans St & Merchandise Mart Plaza", "total_docks": "35", "docks_in_service": "35", "available_docks": "20", "available_bikes": "15", "percent_full": "43", "status": "In Service", "latitude": "41.888243", "longitude": "-87.63639", "location": {"type": "Point", "coordinates": [-87.63639, 41.888243]}, "record": "10020201116115555"}, {"id": "101", "timestamp": "2020-11-16T11:55:55.000", "station_name": "63rd St Beach", "total_docks": "15", "docks_in_service": "15", "available_docks": "3", "available_bikes": "12", "percent_full": "80", "status": "In Service", "latitude": "41.781016372", "longitude": "-87.57611976", "location": {"type": "Point", "coordinates": [-87.5761197602, 41.78101637196]}, "record": "10120201116115555"}, {"id": "102", "timestamp": "2020-11-16T11:55:55.000", "station_name": "Stony Island Ave & 67th St", "total_docks": "11", "docks_in_service": "11", "available_docks": "4", "available_bikes": "7"
# ...

# %%
line.split("Franklin St & Lake St")[0]
# Out:
# '[{"id": "100", "timestamp": "2020-11-16T11:55:55.000", "station_name": "Orleans St & Merchandise Mart Plaza", "total_docks": "35", "docks_in_service": "35", "available_docks": "20", "available_bikes": "15", "percent_full": "43", "status": "In Service", "latitude": "41.888243", "longitude": "-87.63639", "location": {"type": "Point", "coordinates": [-87.63639, 41.888243]}, "record": "10020201116115555"}, {"id": "101", "timestamp": "2020-11-16T11:55:55.000", "station_name": "63rd St Beach", "total_docks": "15", "docks_in_service": "15", "available_docks": "3", "available_bikes": "12", "percent_full": "80", "status": "In Service", "latitude": "41.781016372", "longitude": "-87.57611976", "location": {"type": "Point", "coordinates": [-87.5761197602, 41.78101637196]}, "record": "10120201116115555"}, {"id": "102", "timestamp": "2020-11-16T11:55:55.000", "station_name": "Stony Island Ave & 67th St", "total_docks": "11", "docks_in_service": "11", "available_docks": "4", "available_bikes": "7"
# ...

# %%
a= '[{"id": "100", "timestamp": "2020-11-16T11:55:55.000", "station_name": "Orleans St & Merchandise Mart Plaza", "total_docks": "35", "docks_in_service": "35", "available_docks": "20", "available_bikes": "15", "percent_full": "43", "status": "In Service", "latitude": "41.888243", "longitude": "-87.63639", "location": {"type": "Point", "coordinates": [-87.63639, 41.888243]}, "record": "10020201116115555"}, {"id": "101", "timestamp": "2020-11-16T11:55:55.000", "station_name": "63rd St Beach", "total_docks": "15", "docks_in_service": "15", "available_docks": "3", "available_bikes": "12", "percent_full": "80", "status": "In Service", "latitude": "41.781016372", "longitude": "-87.57611976", "location": {"type": "Point", "coordinates": [-87.5761197602, 41.78101637196]}, "record": "10120201116115555"}]'

# %% [markdown]
# ## id_list

# %%
id_list = []
for i in line.split('"id": '):
    b = i[1:4]
    b = b.replace("{", "")
    b = b.replace('"', "")
    b = b.replace(",", "")
    id_list.append(b)
id_list
# Out:
# ['',
#  '100',
#  '101',
#  '102',
#  '103',
#  '106',
#  '107',
#  '108',
#  '109',
#  '110',
#  '111',
#  '11',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '120',
#  '121',
#  '12',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '130',
#  '131',
#  '13',
#  '132',
#  '133',
#  '134',
#  '135',
#  '136',
#  '137',
#  '138',
#  '140',
#  '141',
#  '483',
#  '14',
#  '142',
#  '143',
#  '143',
#  '143',
#  '143',
#  '144',
#  '144',
#  '144',
#  '145',
#  '146',
#  '147',
#  '148',
#  '149',
#  '150',
#  '15',
#  '152',
#  '153',
#  '154',
#  '156',
#  '157',
#  '158',
#  '159',
#  '160',
#  '161',
#  '16',
#  '162',
#  '163',
#  '164',
#  '165',
#  '166',
#  '167',
#  '168',
#  '169',
#  '170',
#  '171',
#  '17',
#  '172',
#  '173',
#  '174',
#  '175',
#  '176',
#  '177',
#  '178',
#  '179',
#  '180',
#  '181',
#  '18',
#  '182',
#  '183',
#  '184',
#  '185',
#  '186',
#  '188',
#  '190',
#  '191',
#  '19',
# ...

# %% [markdown]
# ## Station Name

# %%
id_list = []
for i in line.split('"station_name": '):
    for x in i.split(","):
        print(x)
#     b = i[1:4]
#     b = b.replace("{", "")
#     b = b.replace('"', "")
#     b = b.replace(",", "")
#     id_list.append(b)
# id_list
# Out:
# [{"id": "100"
#  "timestamp": "2020-11-16T11:55:55.000"
#
# "Orleans St & Merchandise Mart Plaza"
#  "total_docks": "35"
#  "docks_in_service": "35"
#  "available_docks": "20"
#  "available_bikes": "15"
#  "percent_full": "43"
#  "status": "In Service"
#  "latitude": "41.888243"
#  "longitude": "-87.63639"
#  "location": {"type": "Point"
#  "coordinates": [-87.63639
#  41.888243]}
#  "record": "10020201116115555"}
#  {"id": "101"
#  "timestamp": "2020-11-16T11:55:55.000"
#
# "63rd St Beach"
#  "total_docks": "15"
#  "docks_in_service": "15"
#  "available_docks": "3"
#  "available_bikes": "12"
#  "percent_full": "80"
#  "status": "In Service"
#  "latitude": "41.781016372"
#  "longitude": "-87.57611976"
#  "location": {"type": "Point"
#  "coordinates": [-87.5761197602
#  41.78101637196]}
#  "record": "10120201116115555"}
#  {"id": "102"
#  "timestamp": "2020-11-16T11:55:55.000"
#
# "Stony Island Ave & 67th St"
#  "total_docks": "11"
#  "docks_in_service": "11"
# ...

# %%
for x in line.split(","):
    print(x)
# Out:
# [{"id": "100"
#  "timestamp": "2020-11-16T11:55:55.000"
#  "station_name": "Orleans St & Merchandise Mart Plaza"
#  "total_docks": "35"
#  "docks_in_service": "35"
#  "available_docks": "20"
#  "available_bikes": "15"
#  "percent_full": "43"
#  "status": "In Service"
#  "latitude": "41.888243"
#  "longitude": "-87.63639"
#  "location": {"type": "Point"
#  "coordinates": [-87.63639
#  41.888243]}
#  "record": "10020201116115555"}
#  {"id": "101"
#  "timestamp": "2020-11-16T11:55:55.000"
#  "station_name": "63rd St Beach"
#  "total_docks": "15"
#  "docks_in_service": "15"
#  "available_docks": "3"
#  "available_bikes": "12"
#  "percent_full": "80"
#  "status": "In Service"
#  "latitude": "41.781016372"
#  "longitude": "-87.57611976"
#  "location": {"type": "Point"
#  "coordinates": [-87.5761197602
#  41.78101637196]}
#  "record": "10120201116115555"}
#  {"id": "102"
#  "timestamp": "2020-11-16T11:55:55.000"
#  "station_name": "Stony Island Ave & 67th St"
#  "total_docks": "11"
# ...

# %%
b[1]
# Out:
# '"100", "timestamp": "2020-11-16T11:55:55.000", "station_name": "Orleans St & Merchandise Mart Plaza", "total_docks": "35", "docks_in_service": "35", "available_docks": "20", "available_bikes": "15", "percent_full": "43", "status": "In Service", "latitude": "41.888243", "longitude": "-87.63639", "location": {"type": "Point", "coordinates": [-87.63639, 41.888243]}, "record": "10020201116115555"}'

# %%
a
# Out:
# '[{"id": "100", "timestamp": "2020-11-16T11:55:55.000", "station_name": "Orleans St & Merchandise Mart Plaza", "total_docks": "35", "docks_in_service": "35", "available_docks": "20", "available_bikes": "15", "percent_full": "43", "status": "In Service", "latitude": "41.888243", "longitude": "-87.63639", "location": {"type": "Point", "coordinates": [-87.63639, 41.888243]}, "record": "10020201116115555"}'

# %%
sentence = "Your friend Nicky thought you'd like this product from WorldStores",

# %%
a = sentence.split('from ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-f327dcef9f62> in <module>
# ----> 1 a = sentence.split('from ')
#
# NameError: name 'sentence' is not defined

# %%
# Out:
# ['{',
#  '"',
#  'i',
#  'd',
#  '"',
#  ':',
#  ' ',
#  '"',
#  '1',
#  '0',
#  '0',
#  '"',
#  ',',
#  ' ',
#  '"',
#  't',
#  'i',
#  'm',
#  'e',
#  's',
#  't',
#  'a',
#  'm',
#  'p',
#  '"',
#  ':',
#  ' ',
#  '"',
#  '2',
#  '0',
#  '2',
#  '0',
#  '-',
#  '1',
#  '1',
#  '-',
#  '1',
#  '6',
#  'T',
#  '1',
#  '1',
#  ':',
#  '5',
#  '5',
#  ':',
#  '5',
#  '5',
#  '.',
#  '0',
#  '0',
#  '0',
#  '"',
#  ',',
#  ' ',
#  '"',
#  's',
#  't',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  '_',
#  'n',
#  'a',
#  'm',
#  'e',
#  '"',
#  ':',
#  ' ',
#  '"',
#  'O',
#  'r',
#  'l',
#  'e',
#  'a',
#  'n',
#  's',
#  ' ',
#  'S',
#  't',
#  ' ',
#  '&',
#  ' ',
#  'M',
#  'e',
#  'r',
#  'c',
#  'h',
#  'a',
#  'n',
#  'd',
#  'i',
#  's',
#  'e',
#  ' ',
#  'M',
#  'a',
#  'r',
#  't',
#  ' ',
#  'P',
#  'l',
#  'a',
#  'z',
#  'a',
#  '"',
#  ',',
#  ' ',
#  '"',
#  't',
#  'o',
#  't',
#  'a',
#  'l',
#  '_',
#  'd',
#  'o',
#  'c',
#  'k',
#  's',
#  '"',
#  ':',
#  ' ',
#  '"',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-1028c6a7921b> in <module>
# ----> 1 dict(c)
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
f = open( "bdata.txt", "r" )
a = []
for line in f:
    a.append(line)

# %%
a
# Out:
# ['[{"id": "100", "timestamp": "2020-11-16T11:55:55.000", "station_name": "Orleans St & Merchandise Mart Plaza", "total_docks": "35", "docks_in_service": "35", "available_docks": "20", "available_bikes": "15", "percent_full": "43", "status": "In Service", "latitude": "41.888243", "longitude": "-87.63639", "location": {"type": "Point", "coordinates": [-87.63639, 41.888243]}, "record": "10020201116115555"},\n',
#  '{"id": "101", "timestamp": "2020-11-16T11:55:55.000", "station_name": "63rd St Beach", "total_docks": "15", "docks_in_service": "15", "available_docks": "3", "available_bikes": "12", "percent_full": "80", "status": "In Service", "latitude": "41.781016372", "longitude": "-87.57611976", "location": {"type": "Point", "coordinates": [-87.5761197602, 41.78101637196]}, "record": "10120201116115555"},\n',
# ...

# %%
len(a)
# Out:
# 669

# %%
for i in a:
    i.replace("[{", "")
    i.replace("]}", "")
    i.rstrip()

# %%
a
# Out:
# ['[{"id": "100", "timestamp": "2020-11-16T11:55:55.000", "station_name": "Orleans St & Merchandise Mart Plaza", "total_docks": "35", "docks_in_service": "35", "available_docks": "20", "available_bikes": "15", "percent_full": "43", "status": "In Service", "latitude": "41.888243", "longitude": "-87.63639", "location": {"type": "Point", "coordinates": [-87.63639, 41.888243]}, "record": "10020201116115555"},\n',
#  '{"id": "101", "timestamp": "2020-11-16T11:55:55.000", "station_name": "63rd St Beach", "total_docks": "15", "docks_in_service": "15", "available_docks": "3", "available_bikes": "12", "percent_full": "80", "status": "In Service", "latitude": "41.781016372", "longitude": "-87.57611976", "location": {"type": "Point", "coordinates": [-87.5761197602, 41.78101637196]}, "record": "10120201116115555"},\n',
# ...

# %%
dict_stat
# Out:
# ['"id": "100", "timestamp": "2020-11-16T11:55:55.000", "station_name": "Orleans St & Merchandise Mart Plaza", "total_docks": "35", "docks_in_service": "35", "available_docks": "20", "available_bikes": "15", "percent_full": "43", "status": "In Service", "latitude": "41.888243", "longitude": "-87.63639", "location": {"type": "Point", "coordinates": [-87.63639, 41.888243]}, "record": "10020201116115555"},\n',
#  '"id": "101", "timestamp": "2020-11-16T11:55:55.000", "station_name": "63rd St Beach", "total_docks": "15", "docks_in_service": "15", "available_docks": "3", "available_bikes": "12", "percent_full": "80", "status": "In Service", "latitude": "41.781016372", "longitude": "-87.57611976", "location": {"type": "Point", "coordinates": [-87.5761197602, 41.78101637196]}, "record": "10120201116115555"},\n',
# ...

# %%
f = open( "bdata.txt", "r" )
for line in f:
    a = line.replace("[{", '').replace("}")
